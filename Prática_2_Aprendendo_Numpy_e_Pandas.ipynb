# %% [markdown]
# <a href="https://colab.research.google.com/github/aboutdouglas/PosGraduacaoIA/blob/main/Pr%C3%A1tica_2_Aprendendo_Numpy_e_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aplicações de Numpy

# %%
import numpy as np
meu_array = np.array([1, 2, 3, 4, 5])

type(meu_array)

meu_outro_array = np.ndarray(shape=(2,2), dtype=float, order='F')

type(meu_outro_array)

print("este é um array padrão: ", meu_array)
print("este é um ndarray:\n", meu_outro_array)
# Out:
# este é um array padrão:  [1 2 3 4 5]
# este é um ndarray:
#  [[6.92779797e-310 6.92779796e-310]
#  [6.92779796e-310 6.92779795e-310]]

# %%
import numpy as np
meu_array = np.array([1, 2, 3, 4, 5])

data_type = meu_array.dtype

array_shape = meu_array.shape

array_size = meu_array.size

array_item_size = meu_array.itemsize

array_dimension = meu_array.ndim


print("Tipo dos dados: ", data_type)
print("Dimensões: ", array_shape)
print("Tamanho em bytes: ", array_size)
print("Tamanho dos itens: ", array_item_size)
print("Número de Dimensões: ", array_dimension)
# Out:
# Tipo dos dados:  int64
# Dimensões:  (5,)
# Tamanho em bytes:  5
# Tamanho dos itens:  8
# Número de Dimensões:  1

# %%
a = np.array([[1.0, 2.0], [3.0, 4.0]])
b = np.array([[5.0, 6.0], [7.0, 8.0]])

soma = a + b # Soma
diferenca = a - b # Subtração
produto = a * b # Multiplicação
quociente = a / b # Divisão

#multiplação matricial
matrix_product = a.dot(b)

print("Soma: \n", soma)
print("Subtração: \n", diferenca)
print("Multiplicação: \n", produto)
print("Divisão: \n", quociente)
print("Multiplicação Matricial: \n", matrix_product)
# Out:
# Soma:
#  [[ 6.  8.]
#  [10. 12.]]
# Subtração:
#  [[-4. -4.]
#  [-4. -4.]]
# Multiplicação:
#  [[ 5. 12.]
#  [21. 32.]]
# Divisão:
#  [[0.2        0.33333333]
#  [0.42857143 0.5       ]]
# Multiplicação Matricial:
#  [[19. 22.]
#  [43. 50.]]

# %%
import numpy as np
novo_array = np.array([1,2,3,4])
print(novo_array)
matriz = novo_array.reshape(2,2)
print(matriz)
# Out:
# [1 2 3 4]
# [[1 2]
#  [3 4]]

# %%
import numpy as np
v = np.arange(0, 5, 0.5) # cria um array de 0 até 5 com steps de 0.5
print(v)
u = np.linspace(0, 5, 10) # cria um array de 0 até 5 com 10 elementos
print(u)
# Out:
# [0.  0.5 1.  1.5 2.  2.5 3.  3.5 4.  4.5]
# [0.         0.55555556 1.11111111 1.66666667 2.22222222 2.77777778
#  3.33333333 3.88888889 4.44444444 5.        ]

# %% [markdown]
# Aplicação de Pandas

# %%
import pandas as pd

s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])

data = {
'País': ['Bélgica', 'Índia', 'Brasil'],
'Capital': ['Bruxelas', 'Nova Delhi', 'Brasília'],
'População': [123465, 456789, 987654]
}

df = pd.DataFrame(data, columns=['País','Capital','População'])

print("Retorno s:\n", s)
print("Retorno df:\n", df)
# Out:
# Retorno s:
#  a    3
# b   -5
# c    7
# d    4
# dtype: int64
# Retorno df:
#        País     Capital  População
# 0  Bélgica    Bruxelas     123465
# 1    Índia  Nova Delhi     456789
# 2   Brasil    Brasília     987654

# %%
from numpy.ma.core import append
import pandas as pd

s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])

data = {
'País': ['Bélgica', 'Índia', 'Brasil'],
'Capital': ['Bruxelas', 'Nova Delhi', 'Brasília'],
'População': [123465, 456789, 987654]
}

df = pd.DataFrame(data, columns=['País','Capital','População'])

print("Retorno s:\n", s)
print("Retorno df:\n", df)

# adicionando uma nova linha
df2 = pd.DataFrame({
  'País': ['Argentina'],
  'Capital': ['Buenos Aires'],
  'População': [67890]
})
df.append(df2)

# incluindo uma nova coluna
df['Territorio'] = 0

#Removendo linhas pelo index
df.drop([0, 1]) # removendo a linha 0 e a linha 1

#Removendo colunas utilizando o argumento axis=1
df.drop(columns=['Territorio'], axis=1)
# Out:
# Retorno s:
#  a    3
# b   -5
# c    7
# d    4
# dtype: int64
# Retorno df:
#        País     Capital  População
# 0  Bélgica    Bruxelas     123465
# 1    Índia  Nova Delhi     456789
# 2   Brasil    Brasília     987654
#       País     Capital  População
# 0  Bélgica    Bruxelas     123465
# 1    Índia  Nova Delhi     456789
# 2   Brasil    Brasília     987654

# %% [markdown]
# Aprendendo Pandas

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
gamedata = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Pós Graduação/Bases/videogames.csv')
print(gamedata.head(10))

gamedata.columns = ['Ranking', 'Nome', 'Plataforma', 'Ano','Gênero', 'Produtora',
                   'Vendas América do Norte', 'Vendas EUA', 'Vendas Japão', 'Outras vendas', 'Vendas Global']
print(gamedata.shape)
print(gamedata.head(10))

print(gamedata.describe())

# Selecionando uma coluna:
print(gamedata['Nome'])

# Selecionando varias colunas:
print(gamedata[['Nome', 'Ano']])

# pegar da linha 2 até a linha 10:
print(gamedata[['Ranking', 'Nome']][2:10])

# pegar da linha 0 até a linha 15:
print(gamedata[['Ranking', 'Nome']][:15])

# pegar as 8 ultimas linhas:
print(gamedata[['Ranking', 'Nome']][-8:])

# retornando da linha 10 até a linha 20:
print(gamedata[['Ranking', 'Nome']][10:20])

# retornando as 20 últimas linhas dos campos Genero e Ranking:
print(gamedata[['Gênero', 'Ranking']][-20:])

# retornando as 10 primeiras linhas dos campos Vendas USA e Vendas Japão:
print(gamedata[['Vendas EUA', 'Vendas Japão']][:10])

# verificar quais linhas que possuem a coluna Ano nulo:
nullrows = gamedata['Ano'].isnull()
print(gamedata[nullrows].head(5))

# sumarizar dados:
print(gamedata['Plataforma'].value_counts())


df = pd.DataFrame(gamedata, columns=['Nome', 'Vendas EUA'])

# menor valor de um DataFrame:
print(df.min())

# maior valor de um DataFrame:
print(df.max())

# index do menor valor:
#print(df.idxmin())

# index do maior valor:
#print(df.idxmax())

# média de valores:
print(df.mean())

# mediana de valores:
print(df.median())

# soma:
print(df['Vendas EUA'].sum())

# conte a frequencia de cada genero na coluna Gênero:
print(gamedata['Gênero'].value_counts())

# selecione todos os registros em que o campo Ano NÃO é nulo:
notnullrows = gamedata['Ano'].notnull()
print(gamedata[notnullrows].head(5))

# exiba a média das "Vendas no Japão" e "Vendas nos EUA":
print("Média Vendas EUA: ", gamedata['Vendas EUA'].mean())
print("Média Vendas Japão: ", gamedata['Vendas Japão'].mean())

# exiba o valor mínimo de venda na coluna "Outras Vendas":
print("Mínimo Outras vendas: ", gamedata['Outras vendas'].min())

# exiba a soma total das "Outras vendas" e "Vendas Global"
print("Soma de Outras vendas: ", gamedata['Outras vendas'].sum())
print("Soma Vendas Global: ", gamedata['Vendas Global'].sum())

# ordenação de colunas:
print(gamedata.sort_values(['Nome',"Ano"], ascending=True))

# ordene os dados pelo Nome e pela Produtora de forma ascendente:
print(gamedata.sort_values(['Nome', 'Produtora'], ascending=True))

# ordene os dados pelo Ranking e pelo Ano de forma decrescente:
print(gamedata.sort_values(['Ranking', 'Ano'], ascending=False))

# exiba os dados da coluna Plataforma ordenados de forma descrescente pelas "Vendas Globais":
dataf = pd.DataFrame(gamedata, columns=['Plataforma', 'Vendas Global'])
print(dataf.sort_values(['Vendas Global'], ascending=False))

# cruzamento de dados:
cruzamentoDados = pd.crosstab(gamedata['Plataforma'], gamedata['Gênero'])
print(cruzamentoDados.head(10))

# cruzamento dados selecionados:
cruzamentoDados['Total'] = cruzamentoDados.sum(axis=1)
top_platforms = cruzamentoDados[cruzamentoDados['Total'] > 1000]
print(top_platforms.head(10))

# ordene a tabela pela coluna "Total" de forma decrescente:
print(cruzamentoDados.sort_values(['Total'], ascending=False))

# selecione todas as plataformas que tiveram vendas abaixo de 100 unidades do genero Adventure:
df_adv = pd.DataFrame(cruzamentoDados, columns=['Adventure', 'Total'])
top_adventures = df_adv[df_adv['Adventure'] > 100]
print(top_adventures)

# pegue o resultado da atividade anterior e ordene de forma crescente
print(top_adventures.sort_values(['Adventure'], ascending=True))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Ranking                       Nome Plataforma     Ano        Gênero  \
# 0        1                 Wii Sports        Wii  2006.0        Sports
# 1        2          Super Mario Bros.        NES  1985.0      Platform
# 2        3             Mario Kart Wii        Wii  2008.0        Racing
# 3        4          Wii Sports Resort        Wii  2009.0        Sports
# 4        5   Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# 5        6                     Tetris         GB  1989.0        Puzzle
# 6        7      New Super Mario Bros.         DS  2006.0      Platform
# 7        8                   Wii Play        Wii  2006.0          Misc
# 8        9  New Super Mario Bros. Wii        Wii  2009.0      Platform
# 9       10                  Duck Hunt        NES  1984.0       Shooter
#
#   Produtora  Vendas_AN  Vendas_EUA  Vendas_Japao  Outras_vendas  Vendas_Global
# 0  Nintendo      41.49       29.02          3.77           8.46          82.74
# 1  Nintendo      29.08        3.58          6.81           0.77          40.24
# 2  Nintendo      15.85       12.88          3.79           3.31          35.82
# 3  Nintendo      15.75       11.01          3.28           2.96          33.00
# 4  Nintendo      11.27        8.89         10.22           1.00          31.37
# 5  Nintendo      23.20        2.26          4.22           0.58          30.26
# 6  Nintendo      11.38        9.23          6.50           2.90          30.01
# 7  Nintendo      14.03        9.20          2.93           2.85          29.02
# 8  Nintendo      14.59        7.06          4.70           2.26          28.62
# 9  Nintendo      26.93        0.63          0.28           0.47          28.31
# (16598, 11)
#    Ranking                       Nome Plataforma     Ano        Gênero  \
# 0        1                 Wii Sports        Wii  2006.0        Sports
# 1        2          Super Mario Bros.        NES  1985.0      Platform
# 2        3             Mario Kart Wii        Wii  2008.0        Racing
# 3        4          Wii Sports Resort        Wii  2009.0        Sports
# 4        5   Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
# 5        6                     Tetris         GB  1989.0        Puzzle
# 6        7      New Super Mario Bros.         DS  2006.0      Platform
# 7        8                   Wii Play        Wii  2006.0          Misc
# 8        9  New Super Mario Bros. Wii        Wii  2009.0      Platform
# 9       10                  Duck Hunt        NES  1984.0       Shooter
#
#   Produtora  Vendas América do Norte  Vendas EUA  Vendas Japão  Outras vendas  \
# 0  Nintendo                    41.49       29.02          3.77           8.46
# 1  Nintendo                    29.08        3.58          6.81           0.77
# 2  Nintendo                    15.85       12.88          3.79           3.31
# 3  Nintendo                    15.75       11.01          3.28           2.96
# 4  Nintendo                    11.27        8.89         10.22           1.00
# 5  Nintendo                    23.20        2.26          4.22           0.58
# 6  Nintendo                    11.38        9.23          6.50           2.90
# 7  Nintendo                    14.03        9.20          2.93           2.85
# 8  Nintendo                    14.59        7.06          4.70           2.26
# 9  Nintendo                    26.93        0.63          0.28           0.47
#
#    Vendas Global
# 0          82.74
# 1          40.24
# 2          35.82
# 3          33.00
# 4          31.37
# 5          30.26
# 6          30.01
# 7          29.02
# 8          28.62
# 9          28.31
#             Ranking           Ano  Vendas América do Norte    Vendas EUA  \
# count  16598.000000  16327.000000             16598.000000  16598.000000
# mean    8300.605254   2006.406443                 0.264667      0.146652
# std     4791.853933      5.828981                 0.816683      0.505351
# min        1.000000   1980.000000                 0.000000      0.000000
# 25%     4151.250000   2003.000000                 0.000000      0.000000
# 50%     8300.500000   2007.000000                 0.080000      0.020000
# 75%    12449.750000   2010.000000                 0.240000      0.110000
# max    16600.000000   2020.000000                41.490000     29.020000
#
#        Vendas Japão  Outras vendas  Vendas Global
# count  16598.000000   16598.000000   16598.000000
# mean       0.077782       0.048063       0.537441
# std        0.309291       0.188588       1.555028
# min        0.000000       0.000000       0.010000
# 25%        0.000000       0.000000       0.060000
# 50%        0.000000       0.010000       0.170000
# 75%        0.040000       0.040000       0.470000
# max       10.220000      10.570000      82.740000
# 0                                              Wii Sports
# 1                                       Super Mario Bros.
# 2                                          Mario Kart Wii
# 3                                       Wii Sports Resort
# 4                                Pokemon Red/Pokemon Blue
#                                ...
# 16593                  Woody Woodpecker in Crazy Castle 5
# 16594                       Men in Black II: Alien Escape
# 16595    SCORE International Baja 1000: The Official Game
# 16596                                          Know How 2
# 16597                                    Spirits & Spells
# Name: Nome, Length: 16598, dtype: object
#                                                    Nome     Ano
# 0                                            Wii Sports  2006.0
# 1                                     Super Mario Bros.  1985.0
# 2                                        Mario Kart Wii  2008.0
# 3                                     Wii Sports Resort  2009.0
# 4                              Pokemon Red/Pokemon Blue  1996.0
# ...                                                 ...     ...
# 16593                Woody Woodpecker in Crazy Castle 5  2002.0
# 16594                     Men in Black II: Alien Escape  2003.0
# 16595  SCORE International Baja 1000: The Official Game  2008.0
# 16596                                        Know How 2  2010.0
# 16597                                  Spirits & Spells  2003.0
#
# [16598 rows x 2 columns]
#    Ranking                       Nome
# 2        3             Mario Kart Wii
# 3        4          Wii Sports Resort
# 4        5   Pokemon Red/Pokemon Blue
# 5        6                     Tetris
# 6        7      New Super Mario Bros.
# 7        8                   Wii Play
# 8        9  New Super Mario Bros. Wii
# 9       10                  Duck Hunt
#     Ranking                         Nome
# 0         1                   Wii Sports
# 1         2            Super Mario Bros.
# 2         3               Mario Kart Wii
# 3         4            Wii Sports Resort
# 4         5     Pokemon Red/Pokemon Blue
# 5         6                       Tetris
# 6         7        New Super Mario Bros.
# 7         8                     Wii Play
# 8         9    New Super Mario Bros. Wii
# 9        10                    Duck Hunt
# 10       11                   Nintendogs
# 11       12                Mario Kart DS
# 12       13  Pokemon Gold/Pokemon Silver
# 13       14                      Wii Fit
# 14       15                 Wii Fit Plus
#        Ranking                                               Nome
# 16590    16593  Eiyuu Densetsu: Sora no Kiseki Material Collec...
# 16591    16594                                Myst IV: Revelation
# 16592    16595                                           Plushees
# 16593    16596                 Woody Woodpecker in Crazy Castle 5
# 16594    16597                      Men in Black II: Alien Escape
# 16595    16598   SCORE International Baja 1000: The Official Game
# 16596    16599                                         Know How 2
# 16597    16600                                   Spirits & Spells
#     Ranking                                          Nome
# 10       11                                    Nintendogs
# 11       12                                 Mario Kart DS
# 12       13                   Pokemon Gold/Pokemon Silver
# 13       14                                       Wii Fit
# 14       15                                  Wii Fit Plus
# 15       16                            Kinect Adventures!
# 16       17                            Grand Theft Auto V
# 17       18                 Grand Theft Auto: San Andreas
# 18       19                             Super Mario World
# 19       20  Brain Age: Train Your Brain in Minutes a Day
#              Gênero  Ranking
# 16578        Sports    16581
# 16579        Sports    16582
# 16580     Adventure    16583
# 16581        Sports    16584
# 16582        Action    16585
# 16583        Action    16586
# 16584        Puzzle    16587
# 16585       Shooter    16588
# 16586     Adventure    16589
# 16587        Sports    16590
# 16588        Puzzle    16591
# 16589        Action    16592
# 16590  Role-Playing    16593
# 16591     Adventure    16594
# 16592    Simulation    16595
# 16593      Platform    16596
# 16594       Shooter    16597
# 16595        Racing    16598
# 16596        Puzzle    16599
# 16597      Platform    16600
#    Vendas EUA  Vendas Japão
# 0       29.02          3.77
# 1        3.58          6.81
# 2       12.88          3.79
# 3       11.01          3.28
# 4        8.89         10.22
# 5        2.26          4.22
# 6        9.23          6.50
# 7        9.20          2.93
# 8        7.06          4.70
# 9        0.63          0.28
#      Ranking                        Nome Plataforma  Ano    Gênero  \
# 179      180             Madden NFL 2004        PS2  NaN    Sports
# 377      378            FIFA Soccer 2004        PS2  NaN    Sports
# 431      432  LEGO Batman: The Videogame        Wii  NaN    Action
# 470      471  wwe Smackdown vs. Raw 2006        PS2  NaN  Fighting
# 607      608              Space Invaders       2600  NaN   Shooter
#
#                                   Produtora  Vendas América do Norte  \
# 179                         Electronic Arts                     4.26
# 377                         Electronic Arts                     0.59
# 431  Warner Bros. Interactive Entertainment                     1.86
# 470                                     NaN                     1.57
# 607                                   Atari                     2.36
#
#      Vendas EUA  Vendas Japão  Outras vendas  Vendas Global
# 179        0.26          0.01           0.71           5.23
# 377        2.36          0.04           0.51           3.49
# 431        1.02          0.00           0.29           3.17
# 470        1.02          0.00           0.41           3.00
# 607        0.14          0.00           0.03           2.53
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Plataforma, dtype: int64
# Nome          .hack//G.U. Vol.1//Rebirth
# Vendas EUA                           0.0
# dtype: object
# Nome          ¡Shin Chan Flipa en colores!
# Vendas EUA                           29.02
# dtype: object
# Vendas EUA    0.146652
# dtype: float64
# Vendas EUA    0.02
# dtype: float64
# 2434.1299999999997
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: Gênero, dtype: int64
#    Ranking                      Nome Plataforma     Ano        Gênero  \
# 0        1                Wii Sports        Wii  2006.0        Sports
# 1        2         Super Mario Bros.        NES  1985.0      Platform
# 2        3            Mario Kart Wii        Wii  2008.0        Racing
# 3        4         Wii Sports Resort        Wii  2009.0        Sports
# 4        5  Pokemon Red/Pokemon Blue         GB  1996.0  Role-Playing
#
#   Produtora  Vendas América do Norte  Vendas EUA  Vendas Japão  Outras vendas  \
# 0  Nintendo                    41.49       29.02          3.77           8.46
# 1  Nintendo                    29.08        3.58          6.81           0.77
# 2  Nintendo                    15.85       12.88          3.79           3.31
# 3  Nintendo                    15.75       11.01          3.28           2.96
# 4  Nintendo                    11.27        8.89         10.22           1.00
#
#    Vendas Global
# 0          82.74
# 1          40.24
# 2          35.82
# 3          33.00
# 4          31.37
# Média Vendas EUA:  0.14665200626581515
# Média Vendas Japão:  0.077781660441017
# Mínimo Outras vendas:  0.0
# Soma de Outras vendas:  797.7500000000001
# Soma Vendas Global:  8920.44
#        Ranking                                     Nome Plataforma     Ano  \
# 8357      8359               .hack//G.U. Vol.1//Rebirth        PS2  2006.0
# 7107      7109             .hack//G.U. Vol.2//Reminisce        PS2  2006.0
# 8602      8604  .hack//G.U. Vol.2//Reminisce (jp sales)        PS2  2006.0
# 8304      8306            .hack//G.U. Vol.3//Redemption        PS2  2007.0
# 1563      1565                  .hack//Infection Part 1        PS2  2002.0
# ...        ...                                      ...        ...     ...
# 627        628                             uDraw Studio        Wii  2010.0
# 7835      7837             uDraw Studio: Instant Artist        Wii  2011.0
# 15523    15526             uDraw Studio: Instant Artist       X360  2011.0
# 470        471               wwe Smackdown vs. Raw 2006        PS2     NaN
# 9135      9137             ¡Shin Chan Flipa en colores!         DS  2007.0
#
#              Gênero           Produtora  Vendas América do Norte  Vendas EUA  \
# 8357   Role-Playing  Namco Bandai Games                     0.00        0.00
# 7107   Role-Playing  Namco Bandai Games                     0.11        0.09
# 8602   Role-Playing  Namco Bandai Games                     0.00        0.00
# 8304   Role-Playing  Namco Bandai Games                     0.00        0.00
# 1563   Role-Playing               Atari                     0.49        0.38
# ...             ...                 ...                      ...         ...
# 627            Misc                 THQ                     1.67        0.58
# 7835           Misc                 THQ                     0.08        0.09
# 15523          Misc                 THQ                     0.01        0.01
# 470        Fighting                 NaN                     1.57        1.02
# 9135       Platform           505 Games                     0.00        0.00
#
#        Vendas Japão  Outras vendas  Vendas Global
# 8357           0.17           0.00           0.17
# 7107           0.00           0.03           0.23
# 8602           0.16           0.00           0.16
# 8304           0.17           0.00           0.17
# 1563           0.26           0.13           1.27
# ...             ...            ...            ...
# 627            0.00           0.20           2.46
# 7835           0.00           0.02           0.19
# 15523          0.00           0.00           0.02
# 470            0.00           0.41           3.00
# 9135           0.14           0.00           0.14
#
# [16598 rows x 11 columns]
#        Ranking                                     Nome Plataforma     Ano  \
# 8357      8359               .hack//G.U. Vol.1//Rebirth        PS2  2006.0
# 7107      7109             .hack//G.U. Vol.2//Reminisce        PS2  2006.0
# 8602      8604  .hack//G.U. Vol.2//Reminisce (jp sales)        PS2  2006.0
# 8304      8306            .hack//G.U. Vol.3//Redemption        PS2  2007.0
# 1563      1565                  .hack//Infection Part 1        PS2  2002.0
# ...        ...                                      ...        ...     ...
# 627        628                             uDraw Studio        Wii  2010.0
# 7835      7837             uDraw Studio: Instant Artist        Wii  2011.0
# 15523    15526             uDraw Studio: Instant Artist       X360  2011.0
# 470        471               wwe Smackdown vs. Raw 2006        PS2     NaN
# 9135      9137             ¡Shin Chan Flipa en colores!         DS  2007.0
#
#              Gênero           Produtora  Vendas América do Norte  Vendas EUA  \
# 8357   Role-Playing  Namco Bandai Games                     0.00        0.00
# 7107   Role-Playing  Namco Bandai Games                     0.11        0.09
# 8602   Role-Playing  Namco Bandai Games                     0.00        0.00
# 8304   Role-Playing  Namco Bandai Games                     0.00        0.00
# 1563   Role-Playing               Atari                     0.49        0.38
# ...             ...                 ...                      ...         ...
# 627            Misc                 THQ                     1.67        0.58
# 7835           Misc                 THQ                     0.08        0.09
# 15523          Misc                 THQ                     0.01        0.01
# 470        Fighting                 NaN                     1.57        1.02
# 9135       Platform           505 Games                     0.00        0.00
#
#        Vendas Japão  Outras vendas  Vendas Global
# 8357           0.17           0.00           0.17
# 7107           0.00           0.03           0.23
# 8602           0.16           0.00           0.16
# 8304           0.17           0.00           0.17
# 1563           0.26           0.13           1.27
# ...             ...            ...            ...
# 627            0.00           0.20           2.46
# 7835           0.00           0.02           0.19
# 15523          0.00           0.00           0.02
# 470            0.00           0.41           3.00
# 9135           0.14           0.00           0.14
#
# [16598 rows x 11 columns]
#        Ranking                                              Nome Plataforma  \
# 16597    16600                                  Spirits & Spells        GBA
# 16596    16599                                        Know How 2         DS
# 16595    16598  SCORE International Baja 1000: The Official Game        PS2
# 16594    16597                     Men in Black II: Alien Escape         GC
# 16593    16596                Woody Woodpecker in Crazy Castle 5        GBA
# ...        ...                                               ...        ...
# 4            5                          Pokemon Red/Pokemon Blue         GB
# 3            4                                 Wii Sports Resort        Wii
# 2            3                                    Mario Kart Wii        Wii
# 1            2                                 Super Mario Bros.        NES
# 0            1                                        Wii Sports        Wii
#
#           Ano        Gênero   Produtora  Vendas América do Norte  Vendas EUA  \
# 16597  2003.0      Platform     Wanadoo                     0.01        0.00
# 16596  2010.0        Puzzle    7G//AMES                     0.00        0.01
# 16595  2008.0        Racing  Activision                     0.00        0.00
# 16594  2003.0       Shooter  Infogrames                     0.01        0.00
# 16593  2002.0      Platform       Kemco                     0.01        0.00
# ...       ...           ...         ...                      ...         ...
# 4      1996.0  Role-Playing    Nintendo                    11.27        8.89
# 3      2009.0        Sports    Nintendo                    15.75       11.01
# 2      2008.0        Racing    Nintendo                    15.85       12.88
# 1      1985.0      Platform    Nintendo                    29.08        3.58
# 0      2006.0        Sports    Nintendo                    41.49       29.02
#
#        Vendas Japão  Outras vendas  Vendas Global
# 16597          0.00           0.00           0.01
# 16596          0.00           0.00           0.01
# 16595          0.00           0.00           0.01
# 16594          0.00           0.00           0.01
# 16593          0.00           0.00           0.01
# ...             ...            ...            ...
# 4             10.22           1.00          31.37
# 3              3.28           2.96          33.00
# 2              3.79           3.31          35.82
# 1              6.81           0.77          40.24
# 0              3.77           8.46          82.74
#
# [16598 rows x 11 columns]
#       Plataforma  Vendas Global
# 0            Wii          82.74
# 1            NES          40.24
# 2            Wii          35.82
# 3            Wii          33.00
# 4             GB          31.37
# ...          ...            ...
# 16186         PC           0.01
# 16187         PC           0.01
# 16188        PS3           0.01
# 16189         PC           0.01
# 16597        GBA           0.01
#
# [16598 rows x 2 columns]
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# 2600            61          2         2     5         9      11       6
# 3DO              0          1         0     0         0       1       0
# 3DS            182         37        14    53        28      20      11
# DC               3         11        12     0         2       0       6
# DS             343        240        36   393        92     238      67
# GB               6          5         0     8        19      15       2
# GBA            167         38        23   110       142      41      64
# GC             101         20        42    36        73      13      63
# GEN              3          2         5     1         7       0       1
# GG               0          0         0     0         1       0       0
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy
# Plataforma
# 2600                   0       24           1      12         0
# 3DO                    0        0           1       0         0
# 3DS                   86        7          30      26        15
# DC                     4        3           1      10         0
# DS                   200       42         285     148        79
# GB                    21        1           5       9         7
# GBA                   73       40          18      88        18
# GC                    27       48          12     110        11
# GEN                    3        1           0       3         1
# GG                     0        0           0       0         0
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# DS             343        240        36   393        92     238      67
# PS             157         69       108    76        64      32     145
# PS2            348        196       150   222       103      18     216
# PS3            380         74        76   124        37       3      92
# PSP            222        213        74   106        36      44      65
# Wii            238         84        42   280        58      55      94
# X360           324         47        65   126        24       7     105
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# Plataforma
# DS                   200       42         285     148        79   2163
# PS                    97       96          60     222        70   1196
# PS2                  187      160          90     400        71   2161
# PS3                  119      156          31     213        24   1329
# PSP                  192       37          29     135        60   1213
# Wii                   35       66          87     261        25   1325
# X360                  76      203          40     220        28   1265
# Gênero      Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Plataforma
# DS             343        240        36   393        92     238      67
# PS2            348        196       150   222       103      18     216
# PS3            380         74        76   124        37       3      92
# Wii            238         84        42   280        58      55      94
# X360           324         47        65   126        24       7     105
# PSP            222        213        74   106        36      44      65
# PS             157         69       108    76        64      32     145
# PC             165         65         6    24        11      25      60
# XB             155         26        48    46        49       7     123
# GBA            167         38        23   110       142      41      64
# GC             101         20        42    36        73      13      63
# 3DS            182         37        14    53        28      20      11
# PSV            142         86        16    24        10       3      11
# PS4            122         19        17    15        11       1      17
# N64             38          4        29    18        30      12      57
# SNES            12          4        25    17        26      13       9
# XOne            68         12         7    15         4       0      19
# SAT              3         26        31    15         5       5       8
# WiiU            63          3         5    21        16       4       3
# 2600            61          2         2     5         9      11       6
# NES             13          1         4     2        28      14       4
# GB               6          5         0     8        19      15       2
# DC               3         11        12     0         2       0       6
# GEN              3          2         5     1         7       0       1
# NG               0          0        11     0         0       0       0
# SCD              0          0         0     2         1       0       1
# WS               0          0         0     0         0       0       0
# 3DO              0          1         0     0         0       1       0
# TG16             0          1         0     0         0       0       0
# PCFX             0          0         0     0         0       0       0
# GG               0          0         0     0         1       0       0
#
# Gênero      Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# Plataforma
# DS                   200       42         285     148        79   2163
# PS2                  187      160          90     400        71   2161
# PS3                  119      156          31     213        24   1329
# Wii                   35       66          87     261        25   1325
# X360                  76      203          40     220        28   1265
# PSP                  192       37          29     135        60   1213
# PS                    97       96          60     222        70   1196
# PC                   104      148         115      49       188    960
# XB                    23      132          24     170        21    824
# GBA                   73       40          18      88        18    822
# GC                    27       48          12     110        11    556
# 3DS                   86        7          30      26        15    509
# PSV                   83        5           3      23         7    413
# PS4                   47       34           5      43         5    336
# N64                    8       24          10      80         9    319
# SNES                  50       10           9      49        15    239
# XOne                  13       33           3      36         3    213
# SAT                   17       22           7      16        18    173
# WiiU                   6       10           1       8         3    143
# 2600                   0       24           1      12         0    133
# NES                   11        7           0      14         0     98
# GB                    21        1           5       9         7     98
# DC                     4        3           1      10         0     52
# GEN                    3        1           0       3         1     27
# NG                     0        0           0       1         0     12
# SCD                    1        0           0       0         1      6
# WS                     4        0           0       0         2      6
# 3DO                    0        0           1       0         0      3
# TG16                   0        1           0       0         0      2
# PCFX                   1        0           0       0         0      1
# GG                     0        0           0       0         0      1
#             Adventure  Total
# Plataforma
# DS                240   2163
# PS2               196   2161
# PSP               213   1213
#             Adventure  Total
# Plataforma
# PS2               196   2161
# PSP               213   1213
# DS                240   2163
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:62: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:65: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.

# %% [markdown]
# Aprendendo Metplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt


gamedata = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/videogames.csv')

gamedata.columns = ['Ranking', 'Nome', 'Plataforma', 'Ano','Gênero', 'Produtora',
                    'Vendas América do Norte', 'Vendas EUA', 'Vendas Japão', 'Outras vendas', 'Vendas Global']

gamedata['Plataforma'].value_counts().plot()

#plt.savefig('nome_da_imagem.png')
#plt.savefig('nome_da_imagem.png'`, transparent = True)

x = [1, 2, 3, 4, 5, 6, 7, 8, 9]
y = [11, 12, 13, 14, 15, 16, 17, 18, 19]

plt.plot(x, y)
plt.title('SEU TÍTULO')
plt.xlabel('NOME DO EIXO X')
plt.ylabel('NOME DO EIXO Y')
plt.show()


plt.bar(dataf['Plataforma'], dataf['Vendas Global'])
plt.title('VENDAS DE CONSOLE PELO MUNDO')
plt.xlabel('PLATAFORMA')
plt.ylabel('VENDAS')
plt.show()
